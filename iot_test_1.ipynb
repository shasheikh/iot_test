# %%
# Question no 1
"python program to the print all odd number in a list"
numbers = []

user_input = int(input("enter number on element"))
numbers.append(user_input)

for i in range(0, user_input):
  appendelemets = int(input())
  numbers.append(appendelemets)

  print(numbers)

  for number in numbers:
   if(number %2 ==0):
     print(number, "is not odd")
   else:
     print(number, "is odd")
# Out:
# enter number on element2
# 8
# [2, 8]
# 2 is not odd
# 8 is not odd
# 9
# [2, 8, 9]
# 2 is not odd
# 8 is not odd
# 9 is odd

# %%
# Question 2
"""Python program to find the sum of list element"""
numlist = ['1','0','47','44','11','54','28','69','45']
plus=0
for i in numlist:
    plus+=int(i)
print('Sum of List: ',plus)
# Out:
# Sum of List:  299

# %%
# Question 3
"python program tou reverse a list in 2 ways"
numbers = []

user_input = int(input("enter no. of elements "))
numbers.append(user_input)

for i in range(0, user_input):
  appendelemets = int(input())
  numbers.append(appendelemets)

print(numbers[::-1])
# Out:
# enter no. of elements 1
# 2
# [2, 1]

# %%
# Question 4
"python program to the find the top two maximium number in a list"
highest =[200,5,67,87,500,45]
largest_number = highest[1]
for number in highest:
  if number>largest_number:
    largest_number = number
    print(largest_number)
# Out:
# 200
# 500

# %%
# Question 4
"python program to the find the top two maximium number in a list"
numbers = []

user_input = int(input("enetr no. of elements"))
numbers.append(user_input)

for i in range(0,user_input):
  appendelemets = int(input())
  numbers.append(appendelemets)

copy_of_integers = numbers[:]

largest_integers = max(copy_of_integers)

print("first largest number is" , largest_integers)

copy_of_integers.remove(largest_integers)

second_largest_integers = max(copy_of_integers)

print("second largest number is:" , second_largest_integers)
# Out:
# enetr no. of elements8
# 56
# 7
# 8
# 45
# 100
# 67
# 55
# 98
# first largest number is 100
# second largest number is: 98

# %%
# Question 5
"write a program in python to the find second highest number in a list"
nums = []
print("Enter 10 Elements (Numbers) for List: ")
for i in range(10):
  nums.append(int(input()))

large = nums[0]
for i in range(10):
  if large<nums[i]:
    large = nums[i]

secondLarge = nums[0]
for i in range(10):
  if secondLarge<nums[i]:
    if nums[i]!=large:
      secondLarge=nums[i]

print("\nSecond Largest Number is: ")
print(secondLarge)
# Out:
# Enter 10 Elements (Numbers) for List:
# 4
# 9
# 6
# 6
# 2
# 10
# 88
# 45
# 67
# 87
#
# Second Largest Number is:
# 87

# %%
#Question 6
"python program to sort charcters in desending oder"
string = input("enter string")

print(''.join(sorted(string, reverse=True)))
# Out:
# enter stringesha
# shea

# %%
# Question 7
"python program to remove repeated characters form a string"

name=['mubashira' , 'maria' , 'Esha' , 'Shahina' , 'maria' , 'Irha']
name.remove('maria')
print(name)
# Out:
# ['mubashira', 'Esha', 'Shahina', 'maria', 'Irha']

# %%
# Question 8
"""program which check it is vovel or consonant"""
user_input = input("Enter a character: ")

if(user_input =='A' or user_input =='a' or user_input =='E' or user_input =='e' or user_input =='I'
 or user_input =='i' or user_input =='O' or user_input =='o' or user_input =='U' or user_input =='u'):
    print(user_input, "is a Vowel")
else:
    print(user_input, "is a Consonant")
# Out:
# Enter a character: a
# a is a Vowel

# %%
# Question 9
"""Python program to find the factorial of a number provided by the user."""


num = int(input("Enter a number: "))

factorial = 1

if num < 0:
   print("Sorry, factorial does not exist for negative numbers")
elif num == 0:
   print("The factorial of 0 is 1")
else:
   for i in range(1,num + 1):
       factorial = factorial*i
   print("The factorial of",num,"is",factorial)
# Out:
# Enter a number: 4
# The factorial of 4 is 24

# %%
#Question 10
"""program which merge two list"""
list1 = ["a", "b" , "c"]
list2 = [1, 2, 3]

list3 = list1 + list2
print(list3)
# Out:
# ['a', 'b', 'c', 1, 2, 3]
